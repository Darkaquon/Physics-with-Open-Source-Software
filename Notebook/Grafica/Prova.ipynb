# %% [markdown]
# # Titolo
# ## Titolo
# ### Titolo
# #### Titolo
# ##### Titolo
# ###### Titolo
#
# <div id = "colorbox">
#
# This is a demo box to illustr.
#
# </div>

# %%
from IPython.core.display import HTML


css_file = "Stile.css"
HTML(open(css_file, "r").read())
# Out:
# /* Grafica del notebook */
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url("http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf");
# }
#
# /* Main background */
# #notebook_panel {
#     background: rgb(245, 245, 245);
# }
#
# #demobox {
#   background-color: #cfc ;
#   padding: 10px ;
#   position: center;
#   border: 1px solid red ;
# }
#
# /* Formatting for header cells */
# .text_cell_render h1 {
#     font-family: "Merriweather", serif;
#     font-style: regular;
#     font-weight: bold;
#     font-size: 250%;
#     line-height: 100%;
#     color: #FF8000;
#     text-align: center;
#     margin-bottom: 1em;
#     margin-top: 0.5em;
#     display: block;
# }
#
# .text_cell_render h2 {
#     font-family: "Merriweather", serif;
#     font-weight: bold;
#     font-size: 180%;
#     line-height: 100%;
#     color: #0096d6;
#     margin-bottom: 0.5em;
#     margin-top: 0.5em;
#     display: block;
# }
#
# .text_cell_render h3 {
# ...
