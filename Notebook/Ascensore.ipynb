# %%
import numpy as np
import matplotlib.pyplot as plt


def grafico(dimx, dimy, x, y, tit, xlab, ylab):
    plt.figure(figsize=(dimx, dimy))
    plt.plot(x, y, marker='o', markersize=5, markeredgecolor='red', markerfacecolor='red', linestyle='-', linewidth=1, color='black')
    plt.title(tit)
    plt.xlabel(xlab)
    plt.ylabel(ylab)
    plt.grid(True)
    plt.show()


# Altezza in funzione del tempo di salita.
fileName = 'DatiSalita.txt'

t, s = np.loadtxt(fileName, delimiter='\t', unpack=True)

print(t)
print()
print(s)
print()

grafico(10, 5, t, s, 'Altezza in funzione del tempo', 't (s)', 'h (m)')

print()

# Velocità in funzione del tempo di salita.
fileName = 'DatiSalita.txt'
outName = 'Velocità1.txt'

t, s = np.loadtxt(fileName, delimiter='\t', unpack=True)
delta_t = np.diff(t)
delta_s = np.diff(s)
v = delta_s / delta_t

print(v)
print()

t_prime = t[:-1] + (delta_t/2)

print(t_prime)
print()

np.savetxt(outName, np.column_stack((t_prime, v)), delimiter='\t')

grafico(10, 5, t_prime, v, 'Velocità in funzione del tempo', 't (s)', 'v (m/s)')

print()

# Accelerazione in funzione del tempo di salita.
fileName1 = 'Velocità1.txt'
#fileName2 = 'Accelerazionet1.txt'
outName = 'Accelerazione1.txt'

#t2, a2 = np.loadtxt(fileName2, delimiter='\t', unpack=True)

t1, v = np.loadtxt(fileName1, delimiter='\t', unpack=True)
delta_t1 = np.diff(t1)
delta_v = np.diff(v)
a = delta_v / delta_t1

print(a)
print()

t_prime = t[:-1] + (delta_t/2)

print(t_prime)
print()

np.savetxt(outName, np.column_stack((t_prime, a)))

grafico(10, 5, t_prime, a, 'Altezza in funzione del tempo', 't (s)', 'h (m)')
'''
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(t_prime, a, marker='o', markersize=5, markeredgecolor='red', markerfacecolor='red', linestyle='-', linewidth=1, color='black')
plt.title('Accelerazione in funzione del tempo')
plt.xlabel('t (s)')
plt.ylabel('a (m/s^2)')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(t2, a2, marker='o', markersize=5, markeredgecolor='red', markerfacecolor='red', linestyle='-', linewidth=1, color='black')
plt.title('Accelerazione in funzione del tempo')
plt.xlabel('t (s)')
plt.ylabel('a (m/s^2)')
plt.grid(True)
plt.tight_layout()
plt.show()
'''
print()


# Altezza in funzione del tempo di salita e di discesa.
fileName = 'DatiSalitaDiscesa.txt'

t, s = np.loadtxt(fileName, delimiter='\t', unpack=True)

print(t)
print()
print(s)
print()

grafico(10, 5, t, s, 'Altezza in funzione del tempo', 't (s)', 'h (m)')

print()

# Velocità in funzione del tempo di salita e di discesa.
fileName = 'DatiSalitaDiscesa.txt'
outName = 'Velocità2.txt'

t, s = np.loadtxt(fileName, delimiter='\t', unpack=True)
delta_t = np.diff(t)
delta_s = np.diff(s)
v = delta_s / delta_t

print(v)
print()

t_prime = t[:-1] + (delta_t/2)

print(t_prime)
print()

np.savetxt(outName, np.column_stack((t_prime, v)), delimiter='\t')

grafico(10, 5, t_prime, v, 'Velocità in funzione del tempo', 't (s)', 'v (m/s)')

print()

'''
# Accelerazione in funzione del tempo di salita e di discesa.
acc2 = open('Accelerazione2.txt', 'w')
acc2.write('Accelerazione \n')

a = vel2['Velocità'][0] / dati2['Time'][0]
z = str(a)

acc2.write(z)
acc2.write('\n')

for i in range(78):
    a = (vel2['Velocità'][i+1] - vel2['Velocità'][i]) / (dati2['Time'][i+1] - dati2['Time'][i])
    z = str(a)
    
    acc2.write(z)
    acc2.write('\n')

acc2.close()

acc2 = np.genfromtxt('Accelerazione2.txt', delimiter='\t', names=True)
acct2 = np.genfromtxt('Accelerazionet2.txt', delimiter='\t', names=True)

print()
print(acc2)
print()

x1 = dati2['Time']
y1 = acc2['Accelerazione']

x2 = acct2['Time']
y2 = acct2['Acceleration']

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(x1, y1, marker='o', markersize=5, markeredgecolor='red', markerfacecolor='red', linestyle='-', linewidth=1, color='black')
plt.title('Accelerazione in funzione del tempo')
plt.xlabel('t (s)')
plt.ylabel('a (m/s^2)')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(x2, y2, marker='o', markersize=5, markeredgecolor='red', markerfacecolor='red', linestyle='-', linewidth=1, color='black')
plt.title('Accelerazione in funzione del tempo')
plt.xlabel('t (s)')
plt.ylabel('a (m/s^2)')
plt.grid(True)
plt.tight_layout()
plt.show()

print()
'''


# Altezza in funzione del tempo di salita, di discesa e di risalita.
fileName = 'DatiSalitaDiscesaSalita.txt'

t, s = np.loadtxt(fileName, delimiter='\t', unpack=True)

print(t)
print()
print(s)
print()

grafico(10, 5, t, s, 'Altezza in funzione del tempo', 't (s)', 'h (m)')

print()

# Velocità in funzione del tempo di salita, di discesa e di risalita.
fileName = 'DatiSalitaDiscesaSalita.txt'
outName = 'Velocità3.txt'

t, s = np.loadtxt(fileName, delimiter='\t', unpack=True)
delta_t = np.diff(t)
delta_s = np.diff(s)
v = delta_s / delta_t

print(v)
print()

t_prime = t[:-1] + (delta_t/2)

print(t_prime)
print()

np.savetxt(outName, np.column_stack((t_prime, v)), delimiter='\t')

grafico(10, 5, t_prime, v, 'Velocità in funzione del tempo', 't (s)', 'v (m/s)')

print()

'''
# Accelerazione in funzione del tempo di salita, di discesa e di risalita.
acc3 = open('Accelerazione3.txt', 'w')
acc3.write('Accelerazione \n')

a = vel3['Velocità'][0] / dati3['Time'][0]
z = str(a)

acc3.write(z)
acc3.write('\n')

for i in range(107):
    a = (vel3['Velocità'][i+1] - vel3['Velocità'][i]) / (dati3['Time'][i+1] - dati3['Time'][i])
    z = str(a)
    
    acc3.write(z)
    acc3.write('\n')

acc3.close()

acc3 = np.genfromtxt('Accelerazione3.txt', delimiter='\t', names=True)
acct3 = np.genfromtxt('Accelerazionet3.txt', delimiter='\t', names=True)

print()
print(acc3)
print()

x1 = dati3['Time']
y1 = acc3['Accelerazione']

x2 = acct3['Time']
y2 = acct3['Acceleration']

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(x1, y1, marker='o', markersize=5, markeredgecolor='red', markerfacecolor='red', linestyle='-', linewidth=1, color='black')
plt.title('Accelerazione in funzione del tempo')
plt.xlabel('t (s)')
plt.ylabel('a (m/s^2)')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(x2, y2, marker='o', markersize=5, markeredgecolor='red', markerfacecolor='red', linestyle='-', linewidth=1, color='black')
plt.title('Accelerazione in funzione del tempo')
plt.xlabel('t (s)')
plt.ylabel('a (m/s^2)')
plt.grid(True)
plt.tight_layout()
plt.show()

print()
'''
# Out:
# [ 1.00261227  2.00327416  3.00366743  4.10230176  5.10230186  6.20230152
#   7.20230152  8.20230152  9.20230152 10.20230152 11.20230152 12.20230152
#  13.20230152 14.20230152 15.20230152 16.20230152 17.20230152 18.20230152
#  19.30193552 20.40156948 21.50130347 22.50130347 23.6009695  24.70060216
#  25.80030149 26.80030149 27.89993481 28.99956814 30.09930147 31.09930147
#  32.0993018  33.0993018  34.0993018  35.19930147 36.19930147 37.19930147
#  38.19930147 39.19930147 40.19930147 41.19930147 42.19930147 43.1993018
#  44.1993018  45.1993021  46.19968416]
#
# [ 0.          0.07205261  0.05009707  0.13989275  0.09156868  0.13693701
#   0.1594589   0.13100057  0.2047859   0.71989903  1.53489323  2.51016226
#   3.43448453  4.42681518  5.44933755  6.42721419  7.3500511   8.15702345
#   9.13596263 10.18858323 11.11569581 12.12931409 13.24252659 14.21192248
#  15.23784899 16.32807804 17.34589828 18.36657873 19.32978695 20.35867872
# ...
